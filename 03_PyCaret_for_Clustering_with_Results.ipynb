# %% [markdown]
# <a href="https://colab.research.google.com/github/Samarjeet09/ML-Pycaret/blob/main/03_PyCaret_for_Clustering_with_Results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# # **PyCaret for Clustering**
# ---
# - It is a bundle of many Machine Learning algorithms.
# - Only three lines of code is required to compare 20 ML models.
# - Pycaret is available for:
#     - Classification
#     - Regression
#     - Clustering
#
# ---
#
# ### **Self learning resource**
# 1. Tutorial on Pycaret **<a href="https://pycaret.readthedocs.io/en/latest/tutorials.html"> Click Here</a>**
#
# 2. Documentation on Pycaret-Clustering: **<a href="https://pycaret.readthedocs.io/en/latest/api/clustering.html"> Click Here </a>**
#
# ---

# %% [markdown]
# ### **(a) Install Pycaret**

# %%
# !pip install pycaret &> /dev/null
print ("Pycaret installed sucessfully!!")
# Out:
# Pycaret installed sucessfully!!

# %% [markdown]
# ### **(b) Get the version of the pycaret**

# %%
from pycaret.utils import version
version()
# Out:
# '3.0.2'

# %% [markdown]
# ---
# # **1. Clustering - Part 1 (Kmean Clustering)**
# ---
# ### **1.1 Get the list of datasets available in pycaret (55)**

# %%
from pycaret.datasets import get_data
dataSets = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# 17                         telescope  Multivariate
# 18                           titanic  Multivariate
# 19  us_presidential_election_results  Multivariate
# 20                             glass  Multivariate
# 21                              iris  Multivariate
# 22                             poker  Multivariate
# 23                         questions  Multivariate
# 24                         satellite  Multivariate
# 25                               CTG  Multivariate
# 26                          asia_gdp  Multivariate
# 27                         elections  Multivariate
# 28                          facebook  Multivariate
# 29                               ipl  Multivariate
# 30                         jewellery  Multivariate
# 31                              mice  Multivariate
# 32                         migration  Multivariate
# 33                           perfume  Multivariate
# 34                           pokemon  Multivariate
# 35                        population  Multivariate
# 36                     public_health  Multivariate
# 37                             seeds  Multivariate
# 38                         wholesale  Multivariate
# 39                            tweets          Text
# 40                            amazon          Text
# 41                              kiva          Text
# 42                               spx          Text
# 43                         wikipedia          Text
# 44                        automobile  Multivariate
# 45                              bike  Multivariate
# 46                            boston  Multivariate
# 47                          concrete  Multivariate
# 48                           diamond  Multivariate
# 49                            energy  Multivariate
# 50                            forest  Multivariate
# 51                              gold  Multivariate
# 52                             house  Multivariate
# 53                         insurance  Multivariate
# 54                        parkinsons  Multivariate
# 55                           traffic  Multivariate
#
#                    Default Task Target Variable 1 Target Variable 2  \
# 0             Anomaly Detection              None              None
# 1       Association Rule Mining         InvoiceNo       Description
# 2       Association Rule Mining         InvoiceNo       Description
# 3       Classification (Binary)           deposit              None
# 4       Classification (Binary)             Class              None
# 5       Classification (Binary)             Class              None
# 6       Classification (Binary)           default              None
# 7       Classification (Binary)    Class variable              None
# 8       Classification (Binary)             stabf              None
# 9       Classification (Binary)              left              None
# 10      Classification (Binary)             DEATH              None
# 11      Classification (Binary)           Disease              None
# 12      Classification (Binary)             Class              None
# 13      Classification (Binary)       income >50K              None
# 14      Classification (Binary)          Purchase              None
# 15      Classification (Binary)       TARGET_5Yrs              None
# 16      Classification (Binary)              type              None
# 17      Classification (Binary)             Class              None
# 18      Classification (Binary)          Survived              None
# 19      Classification (Binary)      party_winner              None
# 20  Classification (Multiclass)              Type              None
# 21  Classification (Multiclass)           species              None
# 22  Classification (Multiclass)             CLASS              None
# 23  Classification (Multiclass)     Next_Question              None
# 24  Classification (Multiclass)             Class              None
# 25  Classification (Multiclass)               NSP              None
# 26                   Clustering              None              None
# 27                   Clustering              None              None
# 28                   Clustering              None              None
# 29                   Clustering              None              None
# 30                   Clustering              None              None
# 31                   Clustering              None              None
# 32                   Clustering              None              None
# 33                   Clustering              None              None
# 34                   Clustering              None              None
# 35                   Clustering              None              None
# 36                   Clustering              None              None
# 37                   Clustering              None              None
# 38                   Clustering              None              None
# 39                          NLP             tweet              None
# 40         NLP / Classification        reviewText              None
# 41         NLP / Classification                en              None
# 42             NLP / Regression              text              None
# 43         NLP / Classification              Text              None
# 44                   Regression             price              None
# 45                   Regression               cnt              None
# 46                   Regression              medv              None
# 47                   Regression          strength              None
# 48                   Regression             Price              None
# 49                   Regression      Heating Load      Cooling Load
# 50                   Regression              area              None
# 51                   Regression         Gold_T+22              None
# 52                   Regression         SalePrice              None
# 53                   Regression           charges              None
# 54                   Regression               PPE              None
# 55                   Regression    traffic_volume              None
#
#     # Instances  # Attributes Missing Values
# 0          1000            10              N
# 1          8557             8              N
# 2          9495             8              N
# 3         45211            17              N
# 4           748             5              N
# 5           683            10              N
# 6         24000            24              N
# 7           768             9              N
# 8         10000            14              N
# 9         14999            10              N
# 10          200            16              N
# 11          270            14              N
# 12          154            32              Y
# 13        32561            14              Y
# 14         1070            15              N
# 15         1340            21              N
# 16         6498            13              N
# 17        19020            11              N
# 18          891            11              Y
# 19          497             7              N
# 20          214            10              N
# 21          150             5              N
# 22       100000            11              N
# 23          499             4              N
# 24         6435            37              N
# 25         2129            40              Y
# 26           40            11              N
# 27         3195            54              Y
# 28         7050            12              N
# 29          153            25              N
# 30          505             4              N
# 31         1080            82              Y
# 32          233            12              N
# 33           20            29              N
# 34          800            13              Y
# 35          255            56              Y
# 36          224            21              N
# 37          210             7              N
# 38          440             8              N
# 39         8594             2              N
# 40        20000             2              N
# 41         6818             7              N
# 42          874             4              N
# 43          500             3              N
# 44          202            26              Y
# 45        17379            15              N
# 46          506            14              N
# 47         1030             9              N
# 48         6000             8              N
# 49          768            10              N
# 50          517            13              N
# 51         2558           121              N
# 52         1461            81              Y
# 53         1338             7              N
# 54         5875            22              N
# 55        48204             8              N

# %% [markdown]
# ---
# ### **1.2 Get the "jewellery" dataset**
# ---

# %%
jewelleryDataSet = get_data("jewellery")    # SN is 30
# This is unsupervised dataset.
# No target is defined.
# Out:
#    Age  Income  SpendingScore       Savings
# 0   58   77769       0.791329   6559.829923
# 1   59   81799       0.791082   5417.661426
# 2   62   74751       0.702657   9258.992965
# 3   59   74373       0.765680   7346.334504
# 4   87   17760       0.348778  16869.507130

# %% [markdown]
# ---
# ### **1.3 Download the "jewellery" dataset to local system**
# ---

# %%
jewelleryDataSet.to_csv("jewelleryDataSet.csv")
from google.colab import files
#files.download('jewelleryDataSet.csv')

# %% [markdown]
#   ---
# ### **1.4 "Parameter setting"  for clustering model**
# ##### **Train/Test division, applying data pre-processing** {Sampling, Normalization, Transformation, PCA, Handaling of Outliers, Feature Selection}
# ---

# %%
from pycaret.clustering import *
kMeanClusteringParameters = setup(jewelleryDataSet)
# Re-run the code if any error occur
# Out:
# <style type="text/css">
# #T_4e37b_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4e37b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e37b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4e37b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e37b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4e37b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4e37b_row0_col1" class="data row0 col1" >4053</td>
#     </tr>
#     <tr>
#       <th id="T_4e37b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4e37b_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_4e37b_row1_col1" class="data row1 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_4e37b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4e37b_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_4e37b_row2_col1" class="data row2 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_4e37b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4e37b_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_4e37b_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_4e37b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4e37b_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_4e37b_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4e37b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4e37b_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_4e37b_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_4e37b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4e37b_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_4e37b_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_4e37b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4e37b_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_4e37b_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_4e37b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4e37b_row8_col0" class="data row8 col0" >CPU Jobs</td>
#       <td id="T_4e37b_row8_col1" class="data row8 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_4e37b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4e37b_row9_col0" class="data row9 col0" >Use GPU</td>
#       <td id="T_4e37b_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4e37b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4e37b_row10_col0" class="data row10 col0" >Log Experiment</td>
#       <td id="T_4e37b_row10_col1" class="data row10 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4e37b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4e37b_row11_col0" class="data row11 col0" >Experiment Name</td>
#       <td id="T_4e37b_row11_col1" class="data row11 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_4e37b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4e37b_row12_col0" class="data row12 col0" >USI</td>
#       <td id="T_4e37b_row12_col1" class="data row12 col1" >6b2a</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ---
# ### **1.5 Building "KMean" clustering model**
# ---

# %%
for i in range(2,10):
  KMeanClusteringModel = create_model('kmeans', num_clusters=i)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1fbbd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1fbbd_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1fbbd_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_1fbbd_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_1fbbd_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_1fbbd_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_1fbbd_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1fbbd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1fbbd_row0_col0" class="data row0 col0" >0.6547</td>
#       <td id="T_1fbbd_row0_col1" class="data row0 col1" >1277.1723</td>
#       <td id="T_1fbbd_row0_col2" class="data row0 col2" >0.3981</td>
#       <td id="T_1fbbd_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_1fbbd_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_1fbbd_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_cc24f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cc24f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_cc24f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_cc24f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_cc24f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_cc24f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_cc24f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc24f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cc24f_row0_col0" class="data row0 col0" >0.7393</td>
#       <td id="T_cc24f_row0_col1" class="data row0 col1" >3567.5370</td>
#       <td id="T_cc24f_row0_col2" class="data row0 col2" >0.3435</td>
#       <td id="T_cc24f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_cc24f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_cc24f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_52fc9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_52fc9_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_52fc9_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_52fc9_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_52fc9_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_52fc9_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_52fc9_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52fc9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_52fc9_row0_col0" class="data row0 col0" >0.7207</td>
#       <td id="T_52fc9_row0_col1" class="data row0 col1" >5011.8115</td>
#       <td id="T_52fc9_row0_col2" class="data row0 col2" >0.4114</td>
#       <td id="T_52fc9_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_52fc9_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_52fc9_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_c1e50" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1e50_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c1e50_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c1e50_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c1e50_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c1e50_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c1e50_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1e50_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c1e50_row0_col0" class="data row0 col0" >0.6777</td>
#       <td id="T_c1e50_row0_col1" class="data row0 col1" >4685.1995</td>
#       <td id="T_c1e50_row0_col2" class="data row0 col2" >0.4596</td>
#       <td id="T_c1e50_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_c1e50_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_c1e50_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_d6ce8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6ce8_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d6ce8_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d6ce8_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d6ce8_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d6ce8_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d6ce8_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6ce8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d6ce8_row0_col0" class="data row0 col0" >0.5801</td>
#       <td id="T_d6ce8_row0_col1" class="data row0 col1" >4796.4212</td>
#       <td id="T_d6ce8_row0_col2" class="data row0 col2" >0.5695</td>
#       <td id="T_d6ce8_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_d6ce8_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_d6ce8_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_22aa6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22aa6_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_22aa6_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_22aa6_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_22aa6_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_22aa6_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_22aa6_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22aa6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_22aa6_row0_col0" class="data row0 col0" >0.5148</td>
#       <td id="T_22aa6_row0_col1" class="data row0 col1" >5499.5273</td>
#       <td id="T_22aa6_row0_col2" class="data row0 col2" >0.6383</td>
#       <td id="T_22aa6_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_22aa6_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_22aa6_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_f8f82" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8f82_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f8f82_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f8f82_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f8f82_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f8f82_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f8f82_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8f82_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f8f82_row0_col0" class="data row0 col0" >0.5198</td>
#       <td id="T_f8f82_row0_col1" class="data row0 col1" >5793.7262</td>
#       <td id="T_f8f82_row0_col2" class="data row0 col2" >0.6272</td>
#       <td id="T_f8f82_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f8f82_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f8f82_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_e0a61" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0a61_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e0a61_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e0a61_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e0a61_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e0a61_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e0a61_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0a61_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e0a61_row0_col0" class="data row0 col0" >0.5222</td>
#       <td id="T_e0a61_row0_col1" class="data row0 col1" >5877.8383</td>
#       <td id="T_e0a61_row0_col2" class="data row0 col2" >0.6082</td>
#       <td id="T_e0a61_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e0a61_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e0a61_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=4)
# Out:
# <style type="text/css">
# </style>
# <table id="T_74a5b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74a5b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_74a5b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_74a5b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_74a5b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_74a5b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_74a5b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74a5b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_74a5b_row0_col0" class="data row0 col0" >0.7207</td>
#       <td id="T_74a5b_row0_col1" class="data row0 col1" >5011.8115</td>
#       <td id="T_74a5b_row0_col2" class="data row0 col2" >0.4114</td>
#       <td id="T_74a5b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_74a5b_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_74a5b_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **1.6 Assign Model - "Assign the labels" to the dataset**
# ---

# %%
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
#      Age  Income  SpendingScore       Savings    Cluster
# 0     58   77769       0.791329   6559.830078  Cluster 2
# 1     59   81799       0.791082   5417.661621  Cluster 2
# 2     62   74751       0.702657   9258.993164  Cluster 2
# 3     59   74373       0.765680   7346.334473  Cluster 2
# 4     87   17760       0.348778  16869.507812  Cluster 0
# ..   ...     ...            ...           ...        ...
# 500   28  101206       0.387441  14936.775391  Cluster 1
# 501   93   19934       0.203140  17969.693359  Cluster 0
# 502   90   35297       0.355149  16091.402344  Cluster 0
# 503   91   20681       0.354679  18401.087891  Cluster 0
# 504   89   30267       0.289310  14386.351562  Cluster 0
#
# [505 rows x 5 columns]

# %% [markdown]
# ---
# ### **1.7 "Saving" the result**
# ---

# %%
kMeanPrediction.to_csv("KMeanResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %% [markdown]
# ---
# ### **1.8 Download the "result file" to user local system**
# ---

# %%
from google.colab import files
#files.download('KMeanResult.csv')      # Uncomment this line
# Open and Explore result file (KMeanResult.csv).

# %% [markdown]
# ---
# # **2. Clustering: Saving and Loading the Model**
# ---
# ### **2.1 Save the "trained model"**
# ---

# %%
x = save_model(KMeanClusteringModel, 'kMeanClusteringModelFile')
# Out:
# Transformation Pipeline and Model Successfully Saved

# %% [markdown]
# ---
# ### **2.2 Download the "trained model**
# ---

# %%
from google.colab import files
#files.download('kMeanClusteringModelFile.pkl')      # Uncomment this line

# %% [markdown]
# ---
# ### **2.3 Load the model**
# ---
# ##### Use it, while working on **"Anaconda/Jupyter notebook"** on local machine

# %%
KMeanClusteringModel1 = load_model('kMeanClusteringModelFile')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %% [markdown]
# ---
# ### **2.4 Upload and Load the trained model to "Colab Environment"**
# ---
# ##### **Upload the trained model**

# %%
from google.colab import files
#files.upload()                     # Uncomment this line

# %% [markdown]
# ##### **Load the trained model**

# %%
#KMeanClusteringModel1 = load_model('kMeanClusteringModelFile (1)')

# %% [markdown]
# ---
# # **3. Clustering: Cluster the new dataset (Unseen Data)**
# ---
# ### **3.1 Select some data or upload user dataset file**

# %%
# Select top 10 rows
newData = get_data("jewellery").iloc[:10]
# Out:
#    Age  Income  SpendingScore       Savings
# 0   58   77769       0.791329   6559.829923
# 1   59   81799       0.791082   5417.661426
# 2   62   74751       0.702657   9258.992965
# 3   59   74373       0.765680   7346.334504
# 4   87   17760       0.348778  16869.507130

# %% [markdown]
# ---
# ### **3.2 Make prediction on the new dataset (Unseen Data)**
# ---

# %%
newPredictions = predict_model(KMeanClusteringModel, data = newData)
newPredictions
# Out:
#     Age    Income  SpendingScore       Savings    Cluster
# 0  58.0   77769.0       0.791329   6559.829923  Cluster 2
# 1  59.0   81799.0       0.791082   5417.661426  Cluster 2
# 2  62.0   74751.0       0.702657   9258.992965  Cluster 2
# 3  59.0   74373.0       0.765680   7346.334504  Cluster 2
# 4  87.0   17760.0       0.348778  16869.507130  Cluster 0
# 5  29.0  131578.0       0.847034   3535.514352  Cluster 3
# 6  54.0   76500.0       0.785198   6878.884249  Cluster 2
# 7  87.0   42592.0       0.355290  18086.287158  Cluster 0
# 8  83.0   34384.0       0.324719  14783.379086  Cluster 0
# 9  84.0   27693.0       0.367063  17879.558906  Cluster 0

# %% [markdown]
# ---
# ### **3.3 Save the prediction result to csv**
# ---

# %%
newPredictions.to_csv("NewPredictions.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %% [markdown]
# ---
# # **4. Clustering: Ploting the Cluster**
# ---
# ```
# - Cluster PCA Plot (2d)          'cluster'
# - Cluster TSnE (3d)              'tsne'
# - Elbow Plot                     'elbow'
# - Silhouette Plot                'silhouette'
# - Distance Plot                  'distance'
# - Distribution Plot              'distribution'
# ```

# %% [markdown]
# ---
# ### **4.1 Evaluate Cluster Model**
# ---

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# ---
# ### **4.2 2D-plot for Cluster**
# ---

# %%
plot_model(KMeanClusteringModel, plot='cluster')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="8b6f6667-3bc6-4f91-8a0c-6699c714f05a" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b6f6667-3bc6-4f91-8a0c-6699c714f05a")) {                    Plotly.newPlot(                        "8b6f6667-3bc6-4f91-8a0c-6699c714f05a",                        [{"customdata":[[89],[85],[88],[94],[89],[87],[92],[85],[93],[86],[79],[82],[89],[84],[87],[86],[94],[88],[95],[89],[86],[85],[87],[89],[92],[85],[90],[90],[84],[88],[84],[88],[91],[89],[86],[88],[87],[85],[82],[79],[91],[85],[94],[85],[88],[89],[88],[89],[89],[87],[87],[90],[88],[90],[88],[93],[90],[91],[89],[84],[87],[85],[87],[88],[88],[85],[87],[90],[86],[91],[
_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3b28b_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_3b28b_row1_col1" class="data row1 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_3b28b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3b28b_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_3b28b_row2_col1" class="data row2 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_3b28b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3b28b_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_3b28b_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_3b28b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3b28b_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_3b28b_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3b28b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3b28b_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_3b28b_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_3b28b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3b28b_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_3b28b_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_3b28b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3b28b_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_3b28b_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_3b28b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3b28b_row8_col0" class="data row8 col0" >CPU Jobs</td>
#       <td id="T_3b28b_row8_col1" class="data row8 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_3b28b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3b28b_row9_col0" class="data row9 col0" >Use GPU</td>
#       <td id="T_3b28b_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3b28b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3b28b_row10_col0" class="data row10 col0" >Log Experiment</td>
#       <td id="T_3b28b_row10_col1" class="data row10 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3b28b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3b28b_row11_col0" class="data row11 col0" >Experiment Name</td>
#       <td id="T_3b28b_row11_col1" class="data row11 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_3b28b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3b28b_row12_col0" class="data row12 col0" >USI</td>
#       <td id="T_3b28b_row12_col1" class="data row12 col1" >0318</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_3c622" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c622_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_3c622_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_3c622_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_3c622_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_3c622_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_3c622_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c622_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3c622_row0_col0" class="data row0 col0" >0.7393</td>
#       <td id="T_3c622_row0_col1" class="data row0 col1" >3567.5370</td>
#       <td id="T_3c622_row0_col2" class="data row0 col2" >0.3435</td>
#       <td id="T_3c622_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_3c622_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_3c622_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **5.2 For Cluster = 4**
# ---

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *

jewelleryDataSet = get_data('jewellery')
setup(data = jewelleryDataSet)
x = create_model('kmeans', num_clusters = 4)

# %% [markdown]
# ---
# ### **5.3 Other Clustering Algorithms**
# ---
# ```
# - K-Means clustering                 'kmeans'
# - Affinity Propagation               'ap'
# - Mean shift clustering              'meanshift'
# - Spectral Clustering                'sc'
# - Agglomerative Clustering           'hclust'
# - Density-Based Spatial Clustering   'dbscan'
# - OPTICS Clustering                  'optics'
# - Birch Clustering                   'birch'
# - K-Modes clustering                 'kmodes'
# ```

# %% [markdown]
# ---
# # **6. Clustering: Apply "Data Preprocessing"**
# ---
# ### **Read the Dataset**

# %%
from pycaret.clustering import *
from pycaret.datasets import get_data

jewelleryDataSet = get_data('jewellery')
# Out:
#    Age  Income  SpendingScore       Savings
# 0   58   77769       0.791329   6559.829923
# 1   59   81799       0.791082   5417.661426
# 2   62   74751       0.702657   9258.992965
# 3   59   74373       0.765680   7346.334504
# 4   87   17760       0.348778  16869.507130

# %% [markdown]
# ---
# ### **6.1 Model Performance using "Normalization"**
# ---
# ### **6.1.1 Elbow Plot**

# %%
setup(data = jewelleryDataSet, normalize = True, normalize_method = 'zscore')
x = create_model('kmeans')
plot_model(x, plot = 'elbow')

# %% [markdown]
# ---
# ### **6.1.2 For Cluster = 3**
# ---

# %%
setup(data = jewelleryDataSet, normalize = True, normalize_method = 'zscore')
x = create_model('kmeans', num_clusters = 3)
# Out:
# <style type="text/css">
# #T_56862_row4_col1, #T_56862_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_56862" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_56862_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_56862_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56862_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_56862_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_56862_row0_col1" class="data row0 col1" >8442</td>
#     </tr>
#     <tr>
#       <th id="T_56862_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_56862_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_56862_row1_col1" class="data row1 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_56862_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_56862_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_56862_row2_col1" class="data row2 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_56862_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_56862_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_56862_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_56862_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_56862_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_56862_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_56862_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_56862_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_56862_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_56862_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_56862_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_56862_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_56862_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_56862_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_56862_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_56862_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_56862_row8_col0" class="data row8 col0" >Normalize</td>
#       <td id="T_56862_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_56862_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_56862_row9_col0" class="data row9 col0" >Normalize method</td>
#       <td id="T_56862_row9_col1" class="data row9 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_56862_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_56862_row10_col0" class="data row10 col0" >CPU Jobs</td>
#       <td id="T_56862_row10_col1" class="data row10 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_56862_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_56862_row11_col0" class="data row11 col0" >Use GPU</td>
#       <td id="T_56862_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_56862_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_56862_row12_col0" class="data row12 col0" >Log Experiment</td>
#       <td id="T_56862_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_56862_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_56862_row13_col0" class="data row13 col0" >Experiment Name</td>
#       <td id="T_56862_row13_col1" class="data row13 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_56862_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_56862_row14_col0" class="data row14 col0" >USI</td>
#       <td id="T_56862_row14_col1" class="data row14 col1" >c2ab</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_f0177" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f0177_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f0177_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f0177_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f0177_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f0177_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f0177_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0177_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f0177_row0_col0" class="data row0 col0" >0.6963</td>
#       <td id="T_f0177_row0_col1" class="data row0 col1" >1066.5812</td>
#       <td id="T_f0177_row0_col2" class="data row0 col2" >0.5258</td>
#       <td id="T_f0177_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f0177_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f0177_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **6.1.3 For Cluster = 4**
# ---

# %%
setup(data = jewelleryDataSet, normalize = True, normalize_method = 'zscore')
x = create_model('kmeans', num_clusters = 4)

# %% [markdown]
# ---
# ### **6.1.4 For Cluster = 5**
# ---

# %%
setup(data = jewelleryDataSet, normalize = True, normalize_method = 'zscore')
x = create_model('kmeans', num_clusters = 5)
# Out:
# <style type="text/css">
# #T_719f2_row4_col1, #T_719f2_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_719f2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_719f2_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_719f2_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_719f2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_719f2_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_719f2_row0_col1" class="data row0 col1" >2682</td>
#     </tr>
#     <tr>
#       <th id="T_719f2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_719f2_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_719f2_row1_col1" class="data row1 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_719f2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_719f2_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_719f2_row2_col1" class="data row2 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_719f2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_719f2_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_719f2_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_719f2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_719f2_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_719f2_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_719f2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_719f2_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_719f2_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_719f2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_719f2_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_719f2_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_719f2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_719f2_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_719f2_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_719f2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_719f2_row8_col0" class="data row8 col0" >Normalize</td>
#       <td id="T_719f2_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_719f2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_719f2_row9_col0" class="data row9 col0" >Normalize method</td>
#       <td id="T_719f2_row9_col1" class="data row9 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_719f2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_719f2_row10_col0" class="data row10 col0" >CPU Jobs</td>
#       <td id="T_719f2_row10_col1" class="data row10 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_719f2_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_719f2_row11_col0" class="data row11 col0" >Use GPU</td>
#       <td id="T_719f2_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_719f2_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_719f2_row12_col0" class="data row12 col0" >Log Experiment</td>
#       <td id="T_719f2_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_719f2_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_719f2_row13_col0" class="data row13 col0" >Experiment Name</td>
#       <td id="T_719f2_row13_col1" class="data row13 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_719f2_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_719f2_row14_col0" class="data row14 col0" >USI</td>
#       <td id="T_719f2_row14_col1" class="data row14 col1" >f757</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_cc545" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cc545_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_cc545_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_cc545_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_cc545_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_cc545_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_cc545_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc545_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cc545_row0_col0" class="data row0 col0" >0.8049</td>
#       <td id="T_cc545_row0_col1" class="data row0 col1" >3671.3580</td>
#       <td id="T_cc545_row0_col2" class="data row0 col2" >0.2762</td>
#       <td id="T_cc545_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_cc545_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_cc545_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **6.1.5 3D Plot for Cluster = 5**
# ---

# %%
setup(data = jewelleryDataSet, normalize = True, normalize_method = 'zscore')
x = create_model('kmeans', num_clusters = 5)
plot_model(x, plot = 'tsne')
# Out:
# <style type="text/css">
# #T_f1493_row4_col1, #T_f1493_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f1493" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f1493_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f1493_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1493_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f1493_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f1493_row0_col1" class="data row0 col1" >5188</td>
#     </tr>
#     <tr>
#       <th id="T_f1493_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f1493_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_f1493_row1_col1" class="data row1 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_f1493_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f1493_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_f1493_row2_col1" class="data row2 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_f1493_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f1493_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_f1493_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_f1493_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f1493_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_f1493_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f1493_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f1493_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_f1493_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f1493_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f1493_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_f1493_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f1493_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f1493_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_f1493_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_f1493_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f1493_row8_col0" class="data row8 col0" >Normalize</td>
#       <td id="T_f1493_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f1493_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f1493_row9_col0" class="data row9 col0" >Normalize method</td>
#       <td id="T_f1493_row9_col1" class="data row9 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_f1493_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f1493_row10_col0" class="data row10 col0" >CPU Jobs</td>
#       <td id="T_f1493_row10_col1" class="data row10 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f1493_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f1493_row11_col0" class="data row11 col0" >Use GPU</td>
#       <td id="T_f1493_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f1493_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f1493_row12_col0" class="data row12 col0" >Log Experiment</td>
#       <td id="T_f1493_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f1493_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f1493_row13_col0" class="data row13 col0" >Experiment Name</td>
#       <td id="T_f1493_row13_col1" class="data row13 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f1493_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f1493_row14_col0" class="data row14 col0" >USI</td>
#       <td id="T_f1493_row14_col1" class="data row14 col1" >c8fa</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_99bc5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99bc5_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_99bc5_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_99bc5_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_99bc5_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_99bc5_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_99bc5_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99bc5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_
],[56],[61],[56],[61],[59],[62],[59],[59],[59],[57],[59],[61],[67],[63],[56],[59],[58],[61],[55],[59],[59],[60],[60],[67],[56],[62],[57],[57],[53],[63],[61],[57],[60],[61],[61],[56],[59],[64],[59],[61],[62],[55],[62],[66],[57],[61],[64],[64],[59],[58],[59],[58],[56],[65],[60],[63],[60],[58],[55],[58],[62],[62],[66],[58],[53],[55],[54],[59],[61],[60],[56],[55],[59],[62],[59],[63],[65],[56],[62],[58]],"hovertemplate":"Cluster=Cluster 1<br>0=%{x}<br>1=%{y}<br>2=%{z}<br>Feature=%{customdata[0]}<extra></extra>","legendgroup":"Cluster 1","marker":{"color":"#EF553B","opacity":0.7,"symbol":"circle"},"mode":"markers","name":"Cluster 1","scene":"scene","showlegend":true,"x":[0.48606953,4.988056,7.230533,1.8982958,2.3517292,4.72637,4.885562,5.8712616,2.1651473,3.4945126,2.556835,2.7541707,5.316215,4.3870645,4.3977356,7.0882006,6.8028245,4.138008,1.3986988,3.6840348,6.192317,5.5547514,3.4699087,3.5627785,3.1840024,7.0135684,3.8441503,2.2860432,2.7241151,5.0550814, ...

# %% [markdown]
# ---
# ### **6.2 Model Performance using "Transformation"**
# ---
#
# ### **6.2.1 Elbow Plot**

# %%
setup(data = jewelleryDataSet, transformation = True, transformation_method = 'yeo-johnson')
x = create_model('kmeans')
plot_model(x, plot = 'elbow')

# %% [markdown]
# ---
# ### **6.2.2 For Cluster = 3**
# ---

# %%
setup(data = jewelleryDataSet, transformation = True, transformation_method = 'yeo-johnson')
x = create_model('kmeans', num_clusters = 3)

# %% [markdown]
# ---
# ### **6.2.3 For Cluster = 4**
# ---

# %%
setup(data = jewelleryDataSet, transformation = True, transformation_method = 'yeo-johnson')
x = create_model('kmeans', num_clusters = 4)

# %% [markdown]
# ---
# ### **6.2.4 For Cluster = 5**
# ---

# %%
setup(data = jewelleryDataSet, transformation = True, transformation_method = 'yeo-johnson')
x = create_model('kmeans', num_clusters = 5)

# %% [markdown]
# ---
# ### **6.3 Model Performance using "PCA"**
# ---
# ### **6.3.1 Elbow Plot**

# %%
setup(data = jewelleryDataSet, pca = True, pca_method = 'linear')
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# #T_86ae8_row4_col1, #T_86ae8_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_86ae8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86ae8_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_86ae8_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86ae8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_86ae8_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_86ae8_row0_col1" class="data row0 col1" >4274</td>
#     </tr>
#     <tr>
#       <th id="T_86ae8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_86ae8_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_86ae8_row1_col1" class="data row1 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_86ae8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_86ae8_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_86ae8_row2_col1" class="data row2 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_86ae8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_86ae8_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_86ae8_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_86ae8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_86ae8_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_86ae8_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_86ae8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_86ae8_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_86ae8_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_86ae8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_86ae8_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_86ae8_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_86ae8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_86ae8_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_86ae8_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_86ae8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_86ae8_row8_col0" class="data row8 col0" >PCA</td>
#       <td id="T_86ae8_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_86ae8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_86ae8_row9_col0" class="data row9 col0" >PCA method</td>
#       <td id="T_86ae8_row9_col1" class="data row9 col1" >linear</td>
#     </tr>
#     <tr>
#       <th id="T_86ae8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_86ae8_row10_col0" class="data row10 col0" >PCA components</td>
#       <td id="T_86ae8_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_86ae8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_86ae8_row11_col0" class="data row11 col0" >CPU Jobs</td>
#       <td id="T_86ae8_row11_col1" class="data row11 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_86ae8_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_86ae8_row12_col0" class="data row12 col0" >Use GPU</td>
#       <td id="T_86ae8_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_86ae8_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_86ae8_row13_col0" class="data row13 col0" >Log Experiment</td>
#       <td id="T_86ae8_row13_col1" class="data row13 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_86ae8_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_86ae8_row14_col0" class="data row14 col0" >Experiment Name</td>
#       <td id="T_86ae8_row14_col1" class="data row14 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_86ae8_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_86ae8_row15_col0" class="data row15 col0" >USI</td>
#       <td id="T_86ae8_row15_col1" class="data row15 col1" >9872</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_d8666" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8666_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d8666_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d8666_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d8666_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d8666_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d8666_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8666_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d8666_row0_col0" class="data row0 col0" >0.7207</td>
#       <td id="T_d8666_row0_col1" class="data row0 col1" >5011.8115</td>
#       <td id="T_d8666_row0_col2" class="data row0 col2" >0.4114</td>
#       <td id="T_d8666_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_d8666_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_d8666_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **6.3.2 For Cluster = 3**
# ---

# %%
setup(data = jewelleryDataSet, pca = True, pca_method = 'linear')
x = create_model('kmeans', num_clusters = 3)

# %% [markdown]
# ---
# ### **6.3.3 For Cluster = 4**
# ---

# %%
setup(data = jewelleryDataSet, pca = True, pca_method = 'linear')
x = create_model('kmeans', num_clusters = 4)

# %% [markdown]
# ---
# ### **6.3.4 For Cluster = 5**
# ---

# %%
setup(data = jewelleryDataSet, pca = True, pca_method = 'linear')
x = create_model('kmeans', num_clusters = 5)

# %% [markdown]
# ---
# ### **6.4 Model Performance using "Transformation" + "Normalization"**
# ---
# ### **6.4.1 Elbow Plot**

# %%
setup(data = jewelleryDataSet, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson')
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# #T_836dd_row4_col1, #T_836dd_row8_col1, #T_836dd_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_836dd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_836dd_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_836dd_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_836dd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_836dd_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_836dd_row0_col1" class="data row0 col1" >5763</td>
#     </tr>
#     <tr>
#       <th id="T_836dd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_836dd_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_836dd_row1_col1" class="data row1 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_836dd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_836dd_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_836dd_row2_col1" class="data row2 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_836dd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_836dd_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_836dd_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_836dd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_836dd_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_836dd_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_836dd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_836dd_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_836dd_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_836dd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_836dd_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_836dd_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_836dd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_836dd_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_836dd_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_836dd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_836dd_row8_col0" class="data row8 col0" >Transformation</td>
#       <td id="T_836dd_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_836dd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_836dd_row9_col0" class="data row9 col0" >Transformation method</td>
#       <td id="T_836dd_row9_col1" class="data row9 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_836dd_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_836dd_row10_col0" class="data row10 col0" >Normalize</td>
#       <td id="T_836dd_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_836dd_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_836dd_row11_col0" class="data row11 col0" >Normalize method</td>
#       <td id="T_836dd_row11_col1" class="data row11 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_836dd_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_836dd_row12_col0" class="data row12 col0" >CPU Jobs</td>
#       <td id="T_836dd_row12_col1" class="data row12 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_836dd_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_836dd_row13_col0" class="data row13 col0" >Use GPU</td>
#       <td id="T_836dd_row13_col1" class="data row13 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_836dd_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_836dd_row14_col0" class="data row14 col0" >Log Experiment</td>
#       <td id="T_836dd_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_836dd_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_836dd_row15_col0" class="data row15 col0" >Experiment Name</td>
#       <td id="T_836dd_row15_col1" class="data row15 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_836dd_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_836dd_row16_col0" class="data row16 col0" >USI</td>
#       <td id="T_836dd_row16_col1" class="data row16 col1" >e97d</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_66e9f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66e9f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_66e9f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_66e9f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_66e9f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_66e9f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_66e9f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66e9f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_66e9f_row0_col0" class="data row0 col0" >0.7544</td>
#       <td id="T_66e9f_row0_col1" class="data row0 col1" >1467.4682</td>
#       <td id="T_66e9f_row0_col2" class="data row0 col2" >0.3868</td>
#       <td id="T_66e9f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_66e9f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_66e9f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **6.4.2 For Cluster = 3**
# ---

# %%
setup(data = jewelleryDataSet, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson')
x = create_model('kmeans', num_clusters = 3)

# %% [markdown]
# ---
# ### **6.4.3 For Cluster = 4**
# ---

# %%
setup(data = jewelleryDataSet, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson')
x = create_model('kmeans', num_clusters = 4)

# %% [markdown]
# ---
# ### **6.4.4 For Cluster = 5**
# ---

# %%
setup(data = jewelleryDataSet, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson')
x = create_model('kmeans', num_clusters = 5)
# Out:
# <style type="text/css">
# #T_50745_row4_col1, #T_50745_row8_col1, #T_50745_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_50745" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50745_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_50745_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50745_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_50745_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_50745_row0_col1" class="data row0 col1" >3778</td>
#     </tr>
#     <tr>
#       <th id="T_50745_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_50745_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_50745_row1_col1" class="data row1 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_50745_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_50745_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_50745_row2_col1" class="data row2 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_50745_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_50745_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_50745_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_50745_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_50745_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_50745_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_50745_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_50745_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_50745_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_50745_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_50745_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_50745_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_50745_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_50745_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_50745_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_50745_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_50745_row8_col0" class="data row8 col0" >Transformation</td>
#       <td id="T_50745_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_50745_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_50745_row9_col0" class="data row9 col0" >Transformation method</td>
#       <td id="T_50745_row9_col1" class="data row9 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_50745_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_50745_row10_col0" class="data row10 col0" >Normalize</td>
#       <td id="T_50745_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_50745_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_50745_row11_col0" class="data row11 col0" >Normalize method</td>
#       <td id="T_50745_row11_col1" class="data row11 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_50745_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_50745_row12_col0" class="data row12 col0" >CPU Jobs</td>
#       <td id="T_50745_row12_col1" class="data row12 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_50745_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_50745_row13_col0" class="data row13 col0" >Use GPU</td>
#       <td id="T_50745_row13_col1" class="data row13 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_50745_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_50745_row14_col0" class="data row14 col0" >Log Experiment</td>
#       <td id="T_50745_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_50745_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_50745_row15_col0" class="data row15 col0" >Experiment Name</td>
#       <td id="T_50745_row15_col1" class="data row15 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_50745_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_50745_row16_col0" class="data row16 col0" >USI</td>
#       <td id="T_50745_row16_col1" class="data row16 col1" >f786</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_ad3d5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad3d5_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ad3d5_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ad3d5_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ad3d5_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ad3d5_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ad3d5_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad3d5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ad3d5_row0_col0" class="data row0 col0" >0.8063</td>
#       <td id="T_ad3d5_row0_col1" class="data row0 col1" >3503.4024</td>
#       <td id="T_ad3d5_row0_col2" class="data row0 col2" >0.2748</td>
#       <td id="T_ad3d5_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_ad3d5_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_ad3d5_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **6.5 Model Performance using "Transformation" + "Normalization" + "PCA"**
# ---
# ### **6.5.1 Elbow Plot**

# %%
setup(data = jewelleryDataSet, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', pca_method = 'linear')
x = create_model('kmeans')
plot_model(x, plot = 'elbow')

# %% [markdown]
# ---
# ### **6.5.2 For Cluster = 3**
# ---

# %%
setup(data = jewelleryDataSet, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', pca_method = 'linear')
x = create_model('kmeans', num_clusters = 3)
# Out:
# <style type="text/css">
# #T_376e6_row4_col1, #T_376e6_row8_col1, #T_376e6_row10_col1, #T_376e6_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_376e6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_376e6_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_376e6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_376e6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_376e6_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_376e6_row0_col1" class="data row0 col1" >5540</td>
#     </tr>
#     <tr>
#       <th id="T_376e6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_376e6_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_376e6_row1_col1" class="data row1 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_376e6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_376e6_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_376e6_row2_col1" class="data row2 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_376e6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_376e6_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_376e6_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_376e6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_376e6_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_376e6_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_376e6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_376e6_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_376e6_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_376e6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_376e6_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_376e6_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_376e6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_376e6_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_376e6_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_376e6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_376e6_row8_col0" class="data row8 col0" >Transformation</td>
#       <td id="T_376e6_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_376e6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_376e6_row9_col0" class="data row9 col0" >Transformation method</td>
#       <td id="T_376e6_row9_col1" class="data row9 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_376e6_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_376e6_row10_col0" class="data row10 col0" >Normalize</td>
#       <td id="T_376e6_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_376e6_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_376e6_row11_col0" class="data row11 col0" >Normalize method</td>
#       <td id="T_376e6_row11_col1" class="data row11 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_376e6_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_376e6_row12_col0" class="data row12 col0" >PCA</td>
#       <td id="T_376e6_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_376e6_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_376e6_row13_col0" class="data row13 col0" >PCA method</td>
#       <td id="T_376e6_row13_col1" class="data row13 col1" >linear</td>
#     </tr>
#     <tr>
#       <th id="T_376e6_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_376e6_row14_col0" class="data row14 col0" >PCA components</td>
#       <td id="T_376e6_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_376e6_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_376e6_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_376e6_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_376e6_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_376e6_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_376e6_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_376e6_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_376e6_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_376e6_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_376e6_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_376e6_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_376e6_row18_col1" class="data row18 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_376e6_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_376e6_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_376e6_row19_col1" class="data row19 col1" >4efa</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_68584" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68584_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_68584_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_68584_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_68584_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_68584_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_68584_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68584_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_68584_row0_col0" class="data row0 col0" >0.6912</td>
#       <td id="T_68584_row0_col1" class="data row0 col1" >1016.4677</td>
#       <td id="T_68584_row0_col2" class="data row0 col2" >0.5410</td>
#       <td id="T_68584_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_68584_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_68584_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **6.5.3 For Cluster = 4**
# ---

# %%
setup(data = jewelleryDataSet, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', pca_method = 'linear')
x = create_model('kmeans', num_clusters = 4)

# %% [markdown]
# ---
# ### **6.5.4 For Cluster = 5**
# ---

# %%
setup(data = jewelleryDataSet, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', pca_method = 'linear')
x = create_model('kmeans', num_clusters = 5)
# Out:
# <style type="text/css">
# #T_8d724_row4_col1, #T_8d724_row8_col1, #T_8d724_row10_col1, #T_8d724_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_8d724" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d724_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_8d724_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d724_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8d724_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_8d724_row0_col1" class="data row0 col1" >6074</td>
#     </tr>
#     <tr>
#       <th id="T_8d724_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8d724_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_8d724_row1_col1" class="data row1 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_8d724_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8d724_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_8d724_row2_col1" class="data row2 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_8d724_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8d724_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_8d724_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_8d724_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8d724_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_8d724_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8d724_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8d724_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_8d724_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_8d724_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8d724_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_8d724_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_8d724_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8d724_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_8d724_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_8d724_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8d724_row8_col0" class="data row8 col0" >Transformation</td>
#       <td id="T_8d724_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8d724_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8d724_row9_col0" class="data row9 col0" >Transformation method</td>
#       <td id="T_8d724_row9_col1" class="data row9 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_8d724_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8d724_row10_col0" class="data row10 col0" >Normalize</td>
#       <td id="T_8d724_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8d724_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8d724_row11_col0" class="data row11 col0" >Normalize method</td>
#       <td id="T_8d724_row11_col1" class="data row11 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_8d724_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_8d724_row12_col0" class="data row12 col0" >PCA</td>
#       <td id="T_8d724_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8d724_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_8d724_row13_col0" class="data row13 col0" >PCA method</td>
#       <td id="T_8d724_row13_col1" class="data row13 col1" >linear</td>
#     </tr>
#     <tr>
#       <th id="T_8d724_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_8d724_row14_col0" class="data row14 col0" >PCA components</td>
#       <td id="T_8d724_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_8d724_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_8d724_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_8d724_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_8d724_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_8d724_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_8d724_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8d724_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_8d724_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_8d724_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8d724_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_8d724_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_8d724_row18_col1" class="data row18 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_8d724_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_8d724_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_8d724_row19_col1" class="data row19 col1" >640c</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_fe48a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe48a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_fe48a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_fe48a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_fe48a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_fe48a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_fe48a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe48a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fe48a_row0_col0" class="data row0 col0" >0.8063</td>
#       <td id="T_fe48a_row0_col1" class="data row0 col1" >3503.4024</td>
#       <td id="T_fe48a_row0_col2" class="data row0 col2" >0.2748</td>
#       <td id="T_fe48a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_fe48a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_fe48a_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# # **7. Other Clustering Techniques**
# ---
# ```
# K-Means clustering                 'kmeans'
# Affinity Propagation               'ap'
# Mean shift clustering              'meanshift'
# Spectral Clustering                'sc'
# Agglomerative Clustering           'hclust'
# Density-Based Spatial Clustering   'dbscan'
# OPTICS Clustering                  'optics'
# Birch Clustering                   'birch'
# K-Modes clustering                 'kmodes'
# ```

# %% [markdown]
# ---
# ### **7.1 Buildign Agglomerative (Hierarchical) clustering model**
# ---

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *

jewelleryDataSet = get_data('jewellery')
setup(data = jewelleryDataSet)
hierarchicalModel = create_model('hclust', num_clusters=3)
# Out:
#    Age  Income  SpendingScore       Savings
# 0   58   77769       0.791329   6559.829923
# 1   59   81799       0.791082   5417.661426
# 2   62   74751       0.702657   9258.992965
# 3   59   74373       0.765680   7346.334504
# 4   87   17760       0.348778  16869.507130
# <style type="text/css">
# #T_eb9db_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_eb9db" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb9db_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_eb9db_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb9db_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eb9db_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_eb9db_row0_col1" class="data row0 col1" >5486</td>
#     </tr>
#     <tr>
#       <th id="T_eb9db_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eb9db_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_eb9db_row1_col1" class="data row1 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_eb9db_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_eb9db_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_eb9db_row2_col1" class="data row2 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_eb9db_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_eb9db_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_eb9db_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_eb9db_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_eb9db_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_eb9db_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_eb9db_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_eb9db_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_eb9db_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_eb9db_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_eb9db_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_eb9db_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_eb9db_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_eb9db_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_eb9db_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_eb9db_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_eb9db_row8_col0" class="data row8 col0" >CPU Jobs</td>
#       <td id="T_eb9db_row8_col1" class="data row8 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_eb9db_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_eb9db_row9_col0" class="data row9 col0" >Use GPU</td>
#       <td id="T_eb9db_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_eb9db_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_eb9db_row10_col0" class="data row10 col0" >Log Experiment</td>
#       <td id="T_eb9db_row10_col1" class="data row10 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_eb9db_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_eb9db_row11_col0" class="data row11 col0" >Experiment Name</td>
#       <td id="T_eb9db_row11_col1" class="data row11 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_eb9db_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_eb9db_row12_col0" class="data row12 col0" >USI</td>
#       <td id="T_eb9db_row12_col1" class="data row12 col1" >40ff</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_f3f8a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3f8a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f3f8a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f3f8a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f3f8a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f3f8a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f3f8a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3f8a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f3f8a_row0_col0" class="data row0 col0" >0.7391</td>
#       <td id="T_f3f8a_row0_col1" class="data row0 col1" >3542.6251</td>
#       <td id="T_f3f8a_row0_col2" class="data row0 col2" >0.3407</td>
#       <td id="T_f3f8a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f3f8a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f3f8a_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **7.1.1 Assign Model - "Assign the labels" to the dataset**
# ---

# %%
hierarchicalModelPrediction = assign_model(hierarchicalModel)
hierarchicalModelPrediction

# %% [markdown]
# ---
# ### **7.1.2 Evaluate Agglomerative (Hierarchical) Clustering**
# ---

# %%
evaluate_model(hierarchicalModel)

# %% [markdown]
# ---
# ### **7.2 Density-Based Spatial Clustering**
# ---

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *

jewelleryDataSet = get_data('jewellery')
setup(data = jewelleryDataSet)
dbscanModel = create_model('dbscan')
# Out:
#    Age  Income  SpendingScore       Savings
# 0   58   77769       0.791329   6559.829923
# 1   59   81799       0.791082   5417.661426
# 2   62   74751       0.702657   9258.992965
# 3   59   74373       0.765680   7346.334504
# 4   87   17760       0.348778  16869.507130
# <style type="text/css">
# #T_be57e_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_be57e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be57e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_be57e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be57e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_be57e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_be57e_row0_col1" class="data row0 col1" >8033</td>
#     </tr>
#     <tr>
#       <th id="T_be57e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_be57e_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_be57e_row1_col1" class="data row1 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_be57e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_be57e_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_be57e_row2_col1" class="data row2 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_be57e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_be57e_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_be57e_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_be57e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_be57e_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_be57e_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_be57e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_be57e_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_be57e_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_be57e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_be57e_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_be57e_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_be57e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_be57e_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_be57e_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_be57e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_be57e_row8_col0" class="data row8 col0" >CPU Jobs</td>
#       <td id="T_be57e_row8_col1" class="data row8 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_be57e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_be57e_row9_col0" class="data row9 col0" >Use GPU</td>
#       <td id="T_be57e_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_be57e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_be57e_row10_col0" class="data row10 col0" >Log Experiment</td>
#       <td id="T_be57e_row10_col1" class="data row10 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_be57e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_be57e_row11_col0" class="data row11 col0" >Experiment Name</td>
#       <td id="T_be57e_row11_col1" class="data row11 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_be57e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_be57e_row12_col0" class="data row12 col0" >USI</td>
#       <td id="T_be57e_row12_col1" class="data row12 col1" >7271</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_7f691" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f691_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_7f691_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_7f691_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_7f691_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_7f691_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_7f691_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f691_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7f691_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_7f691_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_7f691_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_7f691_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_7f691_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_7f691_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **7.2.1 Assign Model - "Assign the labels" to the dataset**
# ---

# %%
dbscanModelPrediction = assign_model(dbscanModel)
dbscanModelPrediction

# Noisy samples are given the label -1 i.e. 'Cluster -1'
# Out:
#      Age  Income  SpendingScore       Savings     Cluster
# 0     58   77769       0.791329   6559.830078  Cluster -1
# 1     59   81799       0.791082   5417.661621  Cluster -1
# 2     62   74751       0.702657   9258.993164  Cluster -1
# 3     59   74373       0.765680   7346.334473  Cluster -1
# 4     87   17760       0.348778  16869.507812  Cluster -1
# ..   ...     ...            ...           ...         ...
# 500   28  101206       0.387441  14936.775391  Cluster -1
# 501   93   19934       0.203140  17969.693359  Cluster -1
# 502   90   35297       0.355149  16091.402344  Cluster -1
# 503   91   20681       0.354679  18401.087891  Cluster -1
# 504   89   30267       0.289310  14386.351562  Cluster -1
#
# [505 rows x 5 columns]

# %% [markdown]
# ### **Key Points**

# %% [markdown]
# - num_clusters not required for some of the clustering Alorithms (Affinity Propagation ('ap'), Mean shift
#   clustering ('meanshift'), Density-Based Spatial Clustering ('dbscan') and OPTICS Clustering ('optics')).
# - num_clusters param for these models are automatically determined.
#
# - When fit doesn't converge in Affinity Propagation ('ap') model, all datapoints are labelled as -1.
#
# - Noisy samples are given the label -1, when using Density-Based Spatial  ('dbscan') or OPTICS Clustering ('optics').
#
# - OPTICS ('optics') clustering may take longer training times on large datasets.

# %% [markdown]
# ---
# # **8. Deploy the model on AWS**
# ---
# **<a href="https://pycaret.readthedocs.io/en/latest/api/clustering.html#pycaret.clustering.deploy_model">Click Here</a>**
